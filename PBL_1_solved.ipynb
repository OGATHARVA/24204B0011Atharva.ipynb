# %% [markdown]
# # PBL 1 – Solved Practical File
#
# Name:
#
# Roll No:

# %% [markdown]
# ## Practical 1: Simple Python Program

# %%
print('Hello, World!')

# %% [markdown]
# ## Practical 2: Arithmetic Operations

# %%
a = int(input("Enter a: "))
b = int(input("Enter b: "))
print("Sum =", a+b)
print("Difference =", a-b)
print("Product =", a*b)
print("Division =", a/b)

# %% [markdown]
# ## Practical 3: Conditional Statement

# %%
num = int(input("Enter number: "))
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
